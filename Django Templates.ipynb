# %%
src\test_templates\views.py:

# %%
from django.shortcuts import render

from datetime import datetime
from django.contrib import messages

# Create your views here.

from django.shortcuts import render

def productos_view(request):

    productos = [
        {
            "nombre": "laptop gamer",
            "precio": 1500,
            "categoria": "tecnologia"
        },
        {
            "nombre": "mouse rgb",
            "precio": 80,
            "categoria": "accesorios"
        },
        {
            "nombre": "teclado mecanico",
            "precio": 120,
            "categoria": "gaming"
        },
        {
            "nombre": "monitor 4k",
            "precio": 600,
            "categoria": "pantallas"
        },
    ]
 
    return render(request, "productos.html", {
        "productos": productos
    })

# %%
src\test_templates\urls.py:

# %%
src\test_templates\urls.py:
from django.contrib import admin
from django.urls import path, include

#from .views import test_view
from .views import productos_view #<----Para que funcione la practica

urlpatterns = [
    path("admin/", admin.site.urls),
    #path("", test_view),
    
    path('', productos_view, name='productos'), #<----Para que funcione la practica

     
]

# %%
src\templates\productos.html:

# %%
{% extends "base.html" %}

{% block title %}
Productos EBAC
{% endblock %}

{% block content %}

<h2>🛒 Lista de productos EBAC</h2>

{% if productos %}

    {% for producto in productos %}

        <div style="border:1px solid #ccc; padding:15px; margin:10px;">

            <h3>{{ producto.nombre|title }}</h3>

            <p>
                Precio:
                ${{ producto.precio|floatformat:2 }}
            </p>

            <p>
                Categoría:
                {{ producto.categoria|upper }}
            </p>

            {% if forloop.counter|divisibleby:3 %}
                <p>
                    Producto EBAC destacado múltiplo de 3
                </p>
            {% endif %}

        </div>
 
    {% endfor %}

{% else %}

    <p>No hay productos EBAC disponibles.</p>

{% endif %}

{% endblock %}

# %%
src\templates\base.html:

# %%
<!DOCTYPE html>
<html lang="es">
<head>
    <meta charset="UTF-8">
    <title>{% block title %}EBAC{% endblock %}</title>

    <style>
        body{
            font-family: Arial;
            margin:40px;
            background:#f4f4f4;
        }

        .card{
            background:white;
            padding:20px;
            margin-bottom:20px; 
            border-radius:10px;
            box-shadow:0 0 5px rgba(0,0,0,.1);
        }

        .destacado{
            background:#dff0d8;
        }
    </style>

</head>
<body>

<h1>🛒 Sistema Prueba EBAC</h1>

<hr>

{% block content %}
{% endblock %}

</body>
</html>

{% comment %} <body>
    <div class="container">

        {% block content %}
        {% endblock %}
    
    </div>
</body>  {% endcomment %}

# %%
src\templates\includes\card_producto.html:

# %%
<div class="card {% if destacado %}destacado{% endif %}">

    <h3>{{ nombre|title }}</h3>

    <p>
        Precio:
        ${{ precio|floatformat:2 }}
    </p>

    <p>
        Categoría:
        {{ categoria|upper }}
    </p>

</div>

# %%
src\test_templates\urls.py:

# %%
"""
URL configuration for hello project.

The `urlpatterns` list routes URLs to views. For more information please see:
    https://docs.djangoproject.com/en/6.0/topics/http/urls/
Examples:
Function views
    1. Add an import:  from my_app import views
    2. Add a URL to urlpatterns:  path('', views.home, name='home')
Class-based views
    1. Add an import:  from other_app.views import Home
    2. Add a URL to urlpatterns:  path('', Home.as_view(), name='home')
Including another URLconf
    1. Import the include() function: from django.urls import include, path
    2. Add a URL to urlpatterns:  path('blog/', include('blog.urls'))
"""

from django.conf import settings
from django.contrib import admin
from django.urls import include, path
from ventas.views import SalesChartView

urlpatterns = [
    path("up/", include("up.urls")),
    path("", include("pages.urls")),
    path("ecommerce/", include("ecommerce.urls")),
    path("products/", include("products.urls")),  
    
    path("forms/", include("forms_test.urls")),  
    path("admin/", admin.site.urls),
    path('ventas/', include('ventas.urls')),
    
    path("accounts/", include("accounts.urls")), 
    
    path("test_templates/", include("test_templates.urls")),  

    path('productos/', include('test_templates.urls')), # <----para ver el proyecto funcionando
 
]
if not settings.TESTING:
    urlpatterns = [
        *urlpatterns,
        path("__debug__/", include("debug_toolbar.urls")),

    ]
