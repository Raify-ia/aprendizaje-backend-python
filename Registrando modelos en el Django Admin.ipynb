# %%
src\accounts\admin.py

# %%
from django.contrib import admin

from .models import User, GuestEmail
# Register your models here.

admin.site.register(User)
admin.site.register(GuestEmail)

# %%
src\address\admin.py

# %%
from django.contrib import admin

from .models import Address
# Register your models here.

admin.site.register(Address)

# %%
src\billing_profile\admin.py

# %%
from django.contrib import admin

from .models import BillingProfile
# Register your models here.

admin.site.register(BillingProfile)

# %%
src\cart\admin.py

# %%
from django.contrib import admin

from .models import Cart
# Register your models here.

admin.site.register(Cart)

# %%
src\ecommerce\admin.py

# %%
from django.contrib import admin

from .models import ProductModel
# Register your models here.

admin.site.register(ProductModel)

# %%
src\order_manage\admin.py

# %%
from django.contrib import admin

from .models import Order
# Register your models here.

admin.site.register(Order)

# %%
src\products\admin.py

# %%
from django.contrib import admin

from .models import Product

# Register your models here.

admin.site.register(Product)
#admin.site.register(DigitalProduct)
